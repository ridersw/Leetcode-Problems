# %%
#Importing libraries
import random
import numpy as np
import copy

# %%
#list of the cities given
cities="""
Bakersfield
Barstow
carlsbad
Eureka
Fresno
lake Tahoe,So
Las Vegas
Long Beach
Los Angeles
Merced
Modesto
Monterey
Oakland
Palm Springs
Redding
Sacremento
San Bernardino
San diego
San Francisco
Sanjose
San Luis Obispo
Santa Barbara
San Cruz
Santa Rosa
Sequoia Park
Stockton
Yosemite
"""
# converting the cities into list 
cities = [c for c in cities.split('\n') if c != '']

# %%
## encoding the number with names
nameEncoding={}
count=0
for j in cities:
    if j not in nameEncoding:
        nameEncoding[count]=j
        count+=1
print(nameEncoding)
# Out:
# {0: 'Bakersfield', 1: 'Barstow', 2: 'carlsbad', 3: 'Eureka', 4: 'Fresno', 5: 'lake Tahoe,So', 6: 'Las Vegas', 7: 'Long Beach', 8: 'Los Angeles', 9: 'Merced', 10: 'Modesto', 11: 'Monterey', 12: 'Oakland', 13: 'Palm Springs', 14: 'Redding', 15: 'Sacremento', 16: 'San Bernardino', 17: 'San diego', 18: 'San Francisco', 19: 'Sanjose', 20: 'San Luis Obispo', 21: 'Santa Barbara', 22: 'San Cruz', 23: 'Santa Rosa', 24: 'Sequoia Park', 25: 'Stockton', 26: 'Yosemite'}

# %%
#encoding names with numbers
numberEncoding={}
count=0
for j in cities:
    if j not in numberEncoding:
        numberEncoding[j]=count
        count+=1
print(numberEncoding)
# Out:
# {'Bakersfield': 0, 'Barstow': 1, 'carlsbad': 2, 'Eureka': 3, 'Fresno': 4, 'lake Tahoe,So': 5, 'Las Vegas': 6, 'Long Beach': 7, 'Los Angeles': 8, 'Merced': 9, 'Modesto': 10, 'Monterey': 11, 'Oakland': 12, 'Palm Springs': 13, 'Redding': 14, 'Sacremento': 15, 'San Bernardino': 16, 'San diego': 17, 'San Francisco': 18, 'Sanjose': 19, 'San Luis Obispo': 20, 'Santa Barbara': 21, 'San Cruz': 22, 'Santa Rosa': 23, 'Sequoia Park': 24, 'Stockton': 25, 'Yosemite': 26}

# %%
#given distance matrix
distance=np.array([
     [0,129,206,569,107,360,284,144,115,162,200,231,288,226,436,272,174,231,297,252,118,146,258,347,121,227,200],
     [129,0,153,696,236,395,155,139,130,291,329,360,417,123,565,401,71,176,426,381,247,225,387,476,250,356,329],
     [206,153,0,777,315,780,312,82,93,370,406,428,496,116,644,480,827,23,505,460,293,188,466,565,329,435,408],
     [569,696,777,0,462,398,797,713,694,407,369,388,291,795,150,314,43,800,272,317,504,609,349,222,544,356,488],
     [107,236,315,462,0,388,408,251,222,55,93,152,181,333,329,185,281,338,190,145,137,242,151,240,82,120,93],
     [360,395,780,398,388,0,466,479,456,194,156,266,195,435,249,107,436,542,192,197,197,492,229,199,335,131,133],
     [284,155,312,797,408,466,0,314,302,446,484,504,567,276,640,587,228,332,568,524,414,354,524,610,408,510,435],
     [144,139,82,713,251,479,314,0,29,306,344,364,432,112,580,416,68,105,441,396,229,124,402,491,265,371,344],
     [115,130,93,694,222,456,302,29,0,277,315,335,403,111,551,387,59,116,412,367,200,95,373,462,236,342,315],
     [162,291,370,407,55,194,446,306,277,0,37,118,126,388,274,110,336,393,135,115,192,297,118,185,137,65,81],
     [200,329,406,369,93,156,484,344,315,37,0,153,88,426,236,72,374,431,97,82,230,335,114,147,175,27,119],
     [231,360,428,388,152,266,504,364,335,118,153,0,111,446,325,185,394,451,116,71,135,240,45,166,234,140,199],
     [288,417,496,291,181,195,567,432,403,126,88,111,0,514,214,87,462,519,9,40,227,332,72,59,263,75,207],
     [226,123,116,798,333,435,276,112,111,388,426,446,514,0,682,498,52,139,523,478,311,206,484,573,347,453,426],
     [436,565,644,150,329,249,640,580,551,274,236,325,214,682,0,164,610,667,223,254,411,546,286,251,411,209,355],
     [272,401,450,314,155,107,587,416,387,110,72,185,87,498,164,0,446,503,87,114,301,406,146,103,247,45,191],
     [174,71,827,43,281,436,228,68,59,336,374,394,462,52,610,446,0,105,471,426,259,254,432,521,295,401,374],
     [231,176,23,800,338,542,332,105,116,393,431,451,519,139,667,503,105,0,528,483,316,211,489,578,352,458,431],
     [297,426,505,272,190,192,568,441,412,135,97,116,9,523,223,87,471,528,0,45,232,337,77,50,272,84,216],
     [252,381,460,317,145,197,524,396,367,114,82,71,40,478,254,114,426,483,45,0,187,292,32,95,227,69,195],
     [118,247,293,504,137,197,414,229,200,192,230,135,227,311,411,301,259,316,232,187,0,105,180,282,174,256,230],
     [146,225,155,604,242,492,354,124,95,297,335,240,332,206,546,406,254,211,337,292,105,0,285,387,287,361,335],
     [258,387,466,349,349,151,229,524,402,373,118,114,45,72,484,286,146,432,489,77,32,180,285,0,127,233,101,199],
     [347,476,565,222,240,199,610,491,462,185,147,166,59,573,251,103,521,578,50,95,282,357,127,0,322,134,266],
     [121,250,329,544,82,335,408,265,236,137,175,234,263,347,411,247,295,352,272,227,174,287,233,322,0,202,175],
     [227,356,435,356,120,131,520,371,342,65,27,140,75,453,209,45,401,458,84,69,256,361,101,134,202,0,146],
     [200,329,408,488,93,133,435,344,315,81,119,199,207,426,355,91,374,431,216,195,230,335,199,266,175,146,0]],dtype=object)

# %%
# population=30
population=30
#taking 'bakersfield' as start
startingCity=0
crossCount=3

# %%
# function to create the list of the chromosome and only created once 
def startingChromosome(population=30,cities=cities,startingCity=0):
        #empty list for the chromosomes
        chromosomes=[]

        for j in range(population):
            citiesCopy=copy.deepcopy(cities)
            # choosing the first city 
            first=citiesCopy[startingCity]
            # empty list for the single chromosome for each population
            c=[]
            c.append(first)# first city is fixed
            # appending cities except the first one in random order
            for i in random.sample([i for i in range(27) if i!=startingCity],26):
                c.append(cities[i])

            c.append(first)# final city is same as the first
            chromosomes.append(c)
        return chromosomes

# %%
chromosomes=startingChromosome(population,cities,startingCity)
print("Total no of chromosomes ",len(chromosomes))
print(chromosomes)
print("First chromosome",len(chromosomes[0]))
# Out:
# Total no of chromosomes  30
# [['Bakersfield', 'carlsbad', 'Sequoia Park', 'Sanjose', 'Barstow', 'Palm Springs', 'Oakland', 'San Cruz', 'Sacremento', 'San diego', 'San Francisco', 'Santa Rosa', 'Long Beach', 'Yosemite', 'Redding', 'lake Tahoe,So', 'San Bernardino', 'Santa Barbara', 'San Luis Obispo', 'Stockton', 'Eureka', 'Monterey', 'Merced', 'Modesto', 'Los Angeles', 'Fresno', 'Las Vegas', 'Bakersfield'], ['Bakersfield', 'San diego', 'Eureka', 'Sanjose', 'Merced', 'Yosemite', 'Monterey', 'Fresno', 'carlsbad', 'Oakland', 'Los Angeles', 'lake Tahoe,So', 'Las Vegas', 'Stockton', 'Santa Rosa', 'Sequoia Park', 'San Luis Obispo', 'Sacremento', 'Redding', 'San Francisco', 'Barstow', 'Palm Springs', 'San Bernardino', 'San Cruz', 'Modesto', 'Long Beach', 'Santa Barbara', 'Bakersfield'], ['Bakersfield', 'Merced', 'San Francisco', 'San diego', 'Palm Springs', 'San Luis Obispo', 'Santa Rosa', 'Los Angeles', 'Monterey', 'Stockton', 'Santa Barbara', 'San Bernardino', 'Las Vegas', 'Long Beach', 'Sequoia Park', 'lake Tahoe,So', 'carlsbad', 'Sanjose', 'Eureka', 'Sacremento', 'Yosemite', 'Redding', 'Barstow', 'Oakland', 'San Cruz', 'Fresno', 'Modesto', 'Bakersfield'], ['Bakersfield', 'Santa Rosa', 'Merced', 'Sacremento', 'San diego', 'San Bernardino', 'Santa Barbara', 'Palm Springs', 'Oakland', 'lake Tahoe,So', 'Modesto', 'San Cruz', 'Fresno', 'Stockton', 'Las Vegas', 'Eureka', 'Los Angeles', 'carlsbad', 'San Luis Obispo', 'Redding', 'Long Beach', 'Monterey', 'Yosemite', 'Barstow', 'Sanjose', 'Sequoia Park', 'San Francisco', 'Bakersfield'], ['Bakersfield', 'Los Angeles', 'Redding', 'San Luis Obispo', 'Stockton', 'Santa Rosa', 'Fresno', 'Barstow', 'Sacremento', 'San Bernardino', 'Sanjose', 'Eureka', 'San Francisco', 'Sequoia Park', 'carlsbad', 'Modesto', 'Monterey', 'San Cruz', 'Long Beach', 'Merced', 'Palm Springs', 'San diego', 'lake Tahoe,So', 'Santa Barbara', 'Las Vegas', 'Yosemite', 'Oakland', 'Bakersfield'], ['Bakersfield', 'Sacremento', 'Modesto', 'Monterey', 'San Bernardino', 'Merced', 'Las Vegas', 'Los Angeles', 'Long Beach', 'Stockton', 'Yosemite', 'Fresno', 'Sanjose', 'Santa Rosa', 'Sequoia Park', 'carlsbad', 'Eureka', 'Oakland', 'San Luis Obispo', 'lake Tahoe,So', 'Barstow', 'San diego', 'Palm Springs', 'Santa Barbara', 'San Cruz', 'Redding', 'San Francisco', 'Bakersfield'], ['Bakersfield', 'San Cruz', 'Eureka', 'Palm Springs', 'Barstow', 'San diego', 'Long Beach', 'San Francisco', 'Las Vegas', 'Sanjose', 'lake Tahoe,So', 'San Luis Obispo', 'Modesto', 'Monterey', 'Los Angeles', 'Redding', 'Fresno', 'Yosemite', 'carlsbad', 'Stockton', 'Merced', 'San Bernardino', 'Santa Barbara', 'Sequoia Park', 'Santa Rosa', 'Sacremento', 'Oakland', 'Bakersfield'], ['Bakersfield', 'carlsbad', 'Eureka', 'Santa Rosa', 'Sacremento', 'San diego', 'San Bernardino', 'Las Vegas', 'Monterey', 'Long Beach', 'Stockton', 'Yosemite', 'Santa Barbara', 'San Luis Obispo', 'Redding', 'Merced', 'San Cruz', 'Los Angeles', 'Barstow', 'Sanjose', 'Oakland', 'Palm Springs', 'Modesto', 'Fresno', 'lake Tahoe,So', 'Sequoia Park', 'San Francisco', 'Bakersfield'], ['Bakersfield', 'Fresno', 'Las Vegas', 'Santa Barbara', 'Eureka', 'Monterey', 'Barstow', 'Modesto', 'Redding', 'San Luis Obispo', 'San Cruz', 'Palm Springs', 'lake Tahoe,So', 'carlsbad', 'Merced', 'Stockton', 'Yosemite', 'San Bernardino', 'Sanjose', 'Sequoia Park', 'San diego', 'Oakland', 'Santa Rosa', 'San Francisco', 'Sacremento', 'Los Angeles', 'Long Beach', 'Bakersfield'], ['Bakersfield', 'Eureka', 'San Cruz', 'Los Angeles', 'Oakland', 'Sacremento', 'San diego', 'Palm Springs', 'Fresno', 'Sanjose', 'San Francisco', 'Barstow', 'Monterey', 'San Luis Obispo', 'carlsbad', 'Sequoia Park', 'San Bernardino', 'Santa Rosa', 'Modesto', 'Redding', 'Santa Barbara', 'Stockton', 'lake Tahoe,So', 'Long Beach', 'Las Vegas', 'Yosemite', 'Merced', 'Bakersfield'], ['Bakersfield', 'Los Angeles', 'Yosemite', 'carlsbad', 'Eureka', 'Monterey', 'Sacremento', 'Palm Springs', 'Sequoia Park', 'Barstow', 'Las Vegas', 'San Bernardino', 'San diego', 'lake Tahoe,So', 'Fre ...
# First chromosome 28

# %%
# function to calculate the pathDistance (distance of the path)
def pathDistance(population,chromosomes,distance):
        #initializing empty list for the calculated distance
        dist1=[]
        # runned to generate the distance for the every population
        for i in range(population):
            #initial sum of the distance is zero
            c=0
            for j in range(len(chromosomes[0])-1):
              # calculating the distance of the all the path using the distance matrix given with the distances
                c+=distance[numberEncoding[chromosomes[i][j]]][numberEncoding[chromosomes[i][j+1]]]
            dist1.append(c)
        return dist1

# %%
distance1=pathDistance(population,chromosomes,distance)
print(distance1)
# Out:
# [7837, 7623, 8364, 8615, 8685, 7202, 8009, 8050, 7899, 8226, 7511, 8196, 6386, 8308, 8622, 8132, 8672, 7633, 8332, 7173, 7531, 7868, 7984, 7953, 8074, 7832, 8272, 8696, 7501, 8032]

# %%
# function to calculate the rank for the pathDistance produced
# min distance is given the higher rank 
# max distance is given the lower rank
def rank(distance):
  selections={}

  rank=[sorted(distance,reverse=True).index(x)+1 for x in distance]
  pathRank=dict(zip(rank,distance))
  for i,j in pathRank.items():
      selections[j]=(i/(25*24))*100
  return selections

# %%
selections=rank(distance1)
print(selections)
# Out:
# {7837: 3.5000000000000004, 7623: 4.0, 8364: 1.0, 8615: 0.8333333333333334, 8685: 0.33333333333333337, 7202: 4.666666666666667, 8009: 2.666666666666667, 8050: 2.3333333333333335, 7899: 3.166666666666667, 8226: 1.6666666666666667, 7511: 4.333333333333334, 8196: 1.8333333333333333, 6386: 5.0, 8308: 1.3333333333333335, 8622: 0.6666666666666667, 8132: 2.0, 8672: 0.5, 7633: 3.833333333333333, 8332: 1.1666666666666667, 7173: 4.833333333333333, 7531: 4.166666666666666, 7868: 3.3333333333333335, 7984: 2.833333333333333, 7953: 3.0, 8074: 2.166666666666667, 7832: 3.6666666666666665, 8272: 1.5, 8696: 0.16666666666666669, 7501: 4.5, 8032: 2.5}

# %%
# Thought of using 2 cross selections but there are some invalid paths coming 
# using a single cross with 
def recombine(selections,distance,crossCount,chromosomes):
  #chromosomes=startingChromosome(population,cities,startingCity)
  #offSpring1=[]
  a=sorted(list(selections.values()))
  m1=a[-1]
  m2=a[-2]
  key1=[r for r,t in selections.items() if t==m1]
  key2=[r for r,t in selections.items() if t==m2]
  
  parent1=chromosomes[distance.index(key1[0])]
  parent2=chromosomes[distance.index(key2[0])]
  
  
  for i in range(crossCount):
    
    parent1_Crossing=parent1[1:27]
    parent2_Crossing=parent2[1:27]
    
  # print("before",parent2)
    #print(len(parent2))
    #print("parent 1",parent1,key1)
    #print("_______________")
    #print("parent2",parent2,chromosomes[distance.index(key2[0])])
    n1=random.randint(1,27)
    t=len(parent1)
    selected=parent1_Crossing[n1:]
  # print(selected)
    for i in selected:
        parent2_Crossing.remove(i)
    random.shuffle(selected)
    #print("___________________________")
    #new offspring
    parent2=[parent1[0]]+parent2_Crossing+selected+[parent1[-1]]
    #print("after",parent2)
  """
  for cross in range(crossCount):

    
    
    offspring2=parent1[:n1]+parent1[t-n1:t-1]+parent1[n1:t-n1]+parent1[:1]
    offSpring1.extend(parent1[:n1])
    offSpring1.extend(parent1[t-n1:t-1])
    offSpring1.extend(parent1[n1:t-n1])
    offSpring1.extend([parent1[0]])

    #print("offSpring1",len(offspring2),n1)

  """ 
  #print(len(parent2))
  return parent2

# %%
for i in range(500):
  offSpring1=recombine(selections,distance1,4,chromosomes)

# %%
# function to mutation
# exchanging the cities of two randomly generated index 
def mutation(offSpring1,mutationCount):
  for mut in range(mutationCount):
    index1=random.sample([i for i in range(1,27)],1)
    index2=random.sample([i for i in range(1,27)],1)
    
    
    city1=offSpring1[index1[0]]
    city2=offSpring1[index2[0]]

    offSpring1[index1[0]]=city2
    offSpring1[index2[0]]=city1
  # adding the newly generated chromosome to the pool of chromosomes initally created 
  chromosomes.append(offSpring1)
  return chromosomes

# %%
# function to removing the worst gene i.e gene with maximum distance
def removingGenes(population,distance,cities,startingCity,crossCount,mutationCount,steps=15):
  #initial chromomsome creation
  chromosomes=startingChromosome(population,cities,startingCity)
  #print(chromosomes)
  # calculating the fitness score for the generated chromosomes
  distanc=pathDistance(population,chromosomes,distance)
 # print(distanc)
 #getting the rank of the each chromosome
  selections=rank(distanc)
  # new generation calculation with crossing and mutation
  for i in range(steps):
    offspring=recombine(selections,distanc,crossCount,chromosomes)
    newGenes=mutation(offspring,mutationCount)
    newDist=pathDistance(population,newGenes,distance)

#getting the worst index with highest distance
    worstIndex=newDist.index(max(newDist))
# removing the gene with highest distance
    del newGenes[worstIndex]
    del newDist[worstIndex]
# returning the minimum distance and best path
  return min(newDist),chromosomes[newDist.index(min(newDist))]

# %%
removingGenes(population,distance,cities,startingCity,4,3,steps=15)
# Out:
# (6386,
#  ['Bakersfield',
#   'Monterey',
#   'Santa Rosa',
#   'Barstow',
#   'Sanjose',
#   'Stockton',
#   'San Luis Obispo',
#   'Yosemite',
#   'San diego',
#   'Long Beach',
#   'lake Tahoe,So',
#   'Sequoia Park',
#   'Redding',
#   'Fresno',
#   'Sacremento',
#   'San Cruz',
#   'Oakland',
#   'Santa Barbara',
#   'Modesto',
#   'San Francisco',
#   'carlsbad',
#   'Las Vegas',
#   'Palm Springs',
#   'Los Angeles',
#   'Merced',
#   'San Bernardino',
#   'Eureka',
#   'Bakersfield'])

# %%
#To carry out the generations and to get the shortest pathuntill it attains the local minima
iterations=2000

# %%
# function to converge the 
def converge(iterations,cross_prob,mutation_prob):
  #This is the shortest value to multiply with the mutation
  epsilon=1-1/iterations
  # removing gene is caried out 1000 times
  short_d=[]
  for i in range(iterations):
      crossCount=int((1-epsilon)*cross_prob*len(cities)-1)
      mutationCount=int((epsilon*cross_prob*len(cities)-1)/2)
      values = removingGenes(population,distance,cities,startingCity,crossCount,mutationCount,steps=100)
      currentScore = values[0]
      short_d.append(currentScore)
      currentBestGene = values[1]
      epsilon -= 1/iterations
      
      print(f"distance {currentScore} miles") 
  print("shortest path for the problem ",currentBestGene)      
  return currentBestGene,short_d

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# %%
qwe=converge(iterations,0.5,0.3)
# Out:
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# distance 4686 miles
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 qwe=converge(iterations,0.5,0.3)
#
# Cell In [19], line 10, in converge(iterations, cross_prob, mutation_prob)
#       8 crossCount=int((1-epsilon)*cross_prob*len(cities)-1)
#       9 mutationCount=int((epsilon*cross_prob*len(cities)-1)/2)
# ---> 10 values = removingGenes(population,distance,cities,startingCity,crossCount,mutationCount,steps=100)
#      11 currentScore = values[0]
#      12 short_d.append(currentScore)
#
# Cell In [16], line 15, in removingGenes(population, distance, cities, startingCity, crossCount, mutationCount, steps)
#      13     offspring=recombine(selections,distanc,crossCount,chromosomes)
#      14     newGenes=mutation(offspring,mutationCount)
# ---> 15     newDist=pathDistance(population,newGenes,distance)
#      17 #getting the worst index with highest distance
#      18     worstIndex=newDist.index(max(newDist))
#
# Cell In [9], line 11, in pathDistance(population, chromosomes, distance)
#       8     c=0
#       9     for j in range(len(chromosomes[0])-1):
#      10       # calculating the distance of the all the path using the distance matrix given with the distances
# ---> 11         c+=distance[numberEncoding[chromosomes[i][j]]][numberEncoding[chromosomes[i][j+1]]]
#      12     dist1.append(c)
#      13 return dist1
#
# KeyboardInterrupt:

# %%
import seaborn as sns

# %%
#x=[i for i in range(2000)]
#y=qwe[1]
sns.lineplot(x=[i for i in range(2000)],y=qwe[1])
plt.xlabel("generations")
plt.ylabel("distance")
plt.show()

# %%
x=[i for i in range(2000)]
y=qwe[1]
xySpline = make_interp_spline(x, y)
 
# Returns evenly spaced numbers
# over a specified interval.
x1 = np.linspace(min(x), max(x), 100)
y1 = xySpline(x1)
plt.scatter(x,y)
plt.xlabel("generations")
plt.ylabel("distance")
plt.show()
